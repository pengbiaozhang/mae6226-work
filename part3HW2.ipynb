# %%
import math
import numpy
from matplotlib import pyplot
# embed the figures into the notebook
# %matplotlib inline

# %%
N=145
M=100
c=1
x_circle=-0.15
y_circle=0
circle=x_circle+y_circle*1j
r=numpy.linspace(1.15,5,M)
a=numpy.linspace(0, 2*numpy.pi, N)
R, arfa= numpy.meshgrid(r,a)
b=R*numpy.sin(arfa)+R*numpy.cos(arfa)*1j
z=b+circle
zeta=z+c**2/z

# %%
size = 10
x_start, x_end = -6.0, 6.0            
y_start, y_end = -6.0, 6.0 
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.xlim(-6, 6)
pyplot.ylim(-6, 6)
pyplot.scatter(z.real,z.imag)

# %%
size = 10
x_start, x_end = -6.0, 6.0            
y_start, y_end = -6.0, 6.0 
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.xlim(-6, 6)
pyplot.ylim(-6, 6)
pyplot.scatter(zeta.real,zeta.imag)
